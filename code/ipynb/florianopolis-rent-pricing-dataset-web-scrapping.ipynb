# %% [markdown]
# # Setup

# %% [markdown]
# ### Definindo Caminhos de Arquivos

# %%
import sys
sys.path.insert(1, '/kaggle/input/florianpolis-rent-pricing-dataset/code/')
sys.path.insert(1, '/kaggle/input/florianpolis-rent-pricing-dataset/maps/')
sys.path.insert(1, '/kaggle/input/florianpolis-rent-pricing-dataset/data/')
sys.path.insert(1, '/kaggle/input/florianpolis-rent-pricing-dataset/')
for i in sys.path:
    print(i)
# Out:
# /kaggle/working
# /kaggle/input/florianpolis-rent-pricing-dataset/
# /kaggle/input/florianpolis-rent-pricing-dataset/data/
# /kaggle/input/florianpolis-rent-pricing-dataset/maps/
# /kaggle/input/florianpolis-rent-pricing-dataset/code/
# /kaggle/lib/kagglegym
# /kaggle/lib
# /opt/conda/lib/python310.zip
# /opt/conda/lib/python3.10
# /opt/conda/lib/python3.10/lib-dynload
#
# /root/.local/lib/python3.10/site-packages
# /opt/conda/lib/python3.10/site-packages
# /root/src/BigQuery_Helper

# %% [markdown]
# ### Instalando pacotes via requirements.txt

# %%
# !pip install -r /kaggle/input/florianpolis-rent-pricing-dataset/requrements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 50.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 64.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 8.9 MB/s eta 0:00:00
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1257 sha256=53d0d1c01b260248ca8c21d01e04337d72f3317407eda6dc6e77dfb39b3c6c50
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built bs4
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3
#     Uninstalling pytz-2023.3:
#       Successfully uninstalled pytz-2023.3
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.15
# ...

# %% [markdown]
# ### Importando módulos

# %%
# Builtins
from datetime import datetime, date
import requests
import string
import time
import re
import base64
from random import randint

# Bibliotecas Externas
import numpy as np
import pandas as pd
import bs4
import html5lib
from kaggle_secrets import UserSecretsClient

# Módulos Personalizados
from apis import VivaRealApi, GithubApi

# %% [markdown]
# ### Importando chaves de acesso do Github

# %%
# Importação de Chaves para integração com o Github
user_secrets = UserSecretsClient()
github_access_token = user_secrets.get_secret("github_rent_price_monitoring")

# %% [markdown]
# ### Fluxo de Controle

# %%
api = VivaRealApi('florianopolis',delay_seconds=2)
api.ingest_listings(all=False, max_attempts=1)
# Out:
# Current_page: 1
# 36 novos anúncios adicionados na página 1
# Current_page: 179
# 36 novos anúncios adicionados na página 179

# %%
df = api.result_set
df['area'] = df['area'].astype('float')
df['valor'] = df[['valor']].astype('float')
df.plot(kind='scatter',x='area',y='valor')

# %%
git = GithubApi(
    token=github_access_token,
    owner='strangercacaus',
    repo='florianopolis_rent_pricing_monitoring')

# %%
#file_path = 'dataset.csv'
#new_content = api.result_set
#method = 'overwrite'
#git.update_file_content(file_path, new_content, method='overwrite')
